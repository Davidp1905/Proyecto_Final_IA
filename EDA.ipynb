# %%
import pandas as pd

# Cargar el archivo CSV
games = pd.read_csv('nba/NBA_GAMES.csv')
players = pd.read_csv('nba/NBA_PLAYERS.csv')
teams = pd.read_csv('nba/NBA_TEAMS.csv')
playerGames = pd.read_csv('nba/NBA_PLAYER_GAMES.csv')

# %%
games["MATCHUP"].value_counts()
# Out:
# MATCHUP
# BOS @ WAS      3
# OKC vs. HOU    3
# DAL @ OKC      3
# DAL @ GSW      3
# SAC @ NOP      3
#               ..
# CHA @ GSW      1
# CHA @ SAC      1
# CHA @ POR      1
# CHA @ DEN      1
# CHA @ OKC      1
# Name: count, Length: 1698, dtype: int64

# %%
games["WL"].value_counts()
# Out:
# WL
# L    1163
# W    1163
# Name: count, dtype: int64

# %%
games["Team_ID"].value_counts()
# Out:
# Team_ID
# 1610612742    79
# 1610612761    79
# 1610612747    78
# 1610612746    78
# 1610612745    78
# 1610612741    78
# 1610612750    78
# 1610612748    78
# 1610612762    78
# 1610612763    78
# 1610612753    78
# 1610612757    78
# 1610612751    78
# 1610612743    78
# 1610612766    78
# 1610612765    78
# 1610612760    78
# 1610612755    78
# 1610612738    77
# 1610612737    77
# 1610612740    77
# 1610612739    77
# 1610612749    77
# 1610612744    77
# 1610612752    77
# 1610612754    77
# 1610612758    77
# 1610612756    77
# 1610612759    77
# 1610612764    77
# Name: count, dtype: int64

# %%
games["GAME_DATE"].value_counts()
# Out:
# GAME_DATE
# FEB 12, 2025    30
# NOV 04, 2024    30
# DEC 23, 2024    28
# JAN 25, 2025    28
# NOV 27, 2024    28
#                 ..
# DEC 10, 2024     4
# NOV 14, 2024     2
# FEB 19, 2025     2
# DEC 09, 2024     2
# JAN 26, 2025     2
# Name: count, Length: 157, dtype: int64

# %%
import matplotlib.pyplot as plt

games['FG3M'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FG3M (Triples encestados)')
plt.xlabel('Cantidad de Triples')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FG3A'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FG3A (Triples intentados)')
plt.xlabel('Total de Triples Intentados')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FG3_PCT'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FG3_PCT (Triples porcentaje)')
plt.xlabel('Tasa de triples')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FTM'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FTM (Tiros libres encestados)')
plt.xlabel('Tiros libres')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FTA'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FTA (Tiros libres intentados)')
plt.xlabel('Tiros libres')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FT_PCT'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FT_PCT (Tiros libres porcentaje)')
plt.xlabel('Porcentaje de Tiros Libres')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['OREB'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de OREB (Rebotes ofensivos)')
plt.xlabel('Rebotes ofensivos')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['DREB'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de DREB (Rebotes defensivos)')
plt.xlabel('Rebotes defensivos')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['REB'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de REB (Rebotes totales)')
plt.xlabel('Rebotes totales')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['AST'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de AST (Asistencias)')
plt.xlabel('Asistencias')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['STL'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de STL (Robos)')
plt.xlabel('Robos')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['BLK'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de BLK (Tapas)')
plt.xlabel('Cantidad de Tapas')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['TOV'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de TOV (Pérdidas)')
plt.xlabel('Cantidad de Pérdidas')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['PF'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de PF (Faltas personales)')
plt.xlabel('Cantidad de Faltas personales')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['PTS'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de PTS (Puntos)')
plt.xlabel('Cantidad de Puntos')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FGA'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FGA (Tiros de campo intentados)')
plt.xlabel('Cantidad de Tiros de campo intentados')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FGM'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FGM (Tiros de campo encestados)')
plt.xlabel('Cantidad de Tiros de campo encestados')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
games['FG_PCT'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de FGA (Tiros de campo porcentaje)')
plt.xlabel('Cantidad de Tiros de campo porcentaje')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
